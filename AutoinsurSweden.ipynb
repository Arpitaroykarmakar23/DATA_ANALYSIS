# %% [markdown]
# <a href="https://colab.research.google.com/github/Arpitaroykarmakar23/DATA_ANALYSIS/blob/main/AutoinsurSweden.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/content/swedish_insurance.csv')
data
# Out:
#     No_of_Claims  No_of_Payments
# 0            108           392.5
# 1             19            46.2
# 2             13            15.7
# 3            124           422.2
# 4             40           119.4
# ..           ...             ...
# 58             9            87.4
# 59            31           209.8
# 60            14            95.5
# 61            53           244.6
# 62            26           187.5
#
# [63 rows x 2 columns]

# %%
sns.scatterplot(x='No_of_Claims', y= 'No_of_Payments', data=data)
plt.show()
